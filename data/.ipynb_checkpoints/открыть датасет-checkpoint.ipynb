# %% [markdown]
# Импортируем библиотеки и загружаем исходный датафрейм для анализа

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv('../data/_data.csv')
df.head()
# Out:
#    Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 0           0       271271157                 4  Квартира
# 1           1       271634126                 4  Квартира
# 2           2       271173086   4, Оба варианта  Квартира
# 3           3       272197456   4, Оба варианта  Квартира
# 4           4       273614615                 2  Квартира
#
#                           Метро                             Адрес  \
# 0  м. Смоленская (9 мин пешком)     Москва, улица Новый Арбат, 27
# 1  м. Смоленская (8 мин пешком)     Москва, улица Новый Арбат, 27
# 2  м. Смоленская (7 мин пешком)     Москва, улица Новый Арбат, 27
# 3  м. Смоленская (3 мин пешком)  Москва, переулок Плотников, 21С1
# 4   м. Арбатская (7 мин пешком)     Москва, улица Новый Арбат, 15
#
#        Площадь, м2                        Дом   Парковка  \
# 0       200.0/20.0           5/16, Монолитный  подземная
# 1  198.0/95.0/18.0  5/16, Монолитно-кирпичный  подземная
# ...

# %%
pd.set_option('display.max_columns', None)
df.head(4)
# Out:
#    Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 0           0       271271157                 4  Квартира
# 1           1       271634126                 4  Квартира
# 2           2       271173086   4, Оба варианта  Квартира
# 3           3       272197456   4, Оба варианта  Квартира
#
#                           Метро                             Адрес  \
# 0  м. Смоленская (9 мин пешком)     Москва, улица Новый Арбат, 27
# 1  м. Смоленская (8 мин пешком)     Москва, улица Новый Арбат, 27
# 2  м. Смоленская (7 мин пешком)     Москва, улица Новый Арбат, 27
# 3  м. Смоленская (3 мин пешком)  Москва, переулок Плотников, 21С1
#
#        Площадь, м2                        Дом   Парковка  \
# 0       200.0/20.0           5/16, Монолитный  подземная
# 1  198.0/95.0/18.0  5/16, Монолитно-кирпичный  подземная
# 2  200.0/116.0/4.0                       5/16  подземная
# 3  170.0/95.0/17.0                        5/6  подземная
#
# ...

# %%
# сколько и где пропуски
df.isna().sum()
# 23368 rows × 25 columns
# 1. заполняем пропуски:
# судя по пропускам можно удалить столбец "Серия дома" и может и "Название ЖК" - или тут просто в пропуски написать "Unknown"
# "Количество комнат" заполним медианой(Можно заполнить медианой по типу квартиры или району метро)
# "Метро" заполним "Unknown"
# "Парковка" заполним False
# "Ремонт" заполним "Unknown" или "нет данных" или модой
# "Площадь комнат, м2 " заполним "Unknown" (Можно заполнить медианой по количеству комнат или общей площади)
# "Балкон" заполним 0(значит нет балкона) или False
# "Окна" заполним модой
# "Санузел" заполним модой
# "Можно с детьми/животными" заполним "нет данных"
# "Дополнительно" заполним "нет данных"
# "Название ЖК" заполним "Unknown" или удалим стобец
# "Серия дома" удалить столбец
# "Высота потолков" заполним "Unknown" или медианой по серии дома или модой
# "Лифт" заполним False
# "Мусоропровод" False
# Out:
# Unnamed: 0                      0
# ID  объявления                  0
# Количество комнат            1041
# Тип                             0
# Метро                        1315
# Адрес                           0
# Площадь, м2                     0
# Дом                             0
# Парковка                    13417
# Цена                            0
# Телефоны                        0
# Описание                        0
# Ремонт                       2755
# Площадь комнат, м2           8910
# Балкон                       7978
# Окна                         6613
# Санузел                      2672
# Можно с детьми/животными     6096
# Дополнительно                 357
# Название ЖК                 17520
# Серия дома                  21205
# Высота потолков, м          12162
# Лифт                         5500
# Мусоропровод                10522
# Ссылка на объявление            0
# dtype: int64

# %%
df
# Out:
#        Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 0               0       271271157                 4  Квартира
# 1               1       271634126                 4  Квартира
# 2               2       271173086   4, Оба варианта  Квартира
# 3               3       272197456   4, Оба варианта  Квартира
# 4               4       273614615                 2  Квартира
# ...           ...             ...               ...       ...
# 23363       23363       215565511               NaN  Квартира
# 23364       23364       274654844                 1  Квартира
# 23365       23365       268679909   2, Оба варианта  Квартира
# 23366       23366       274807525                 2  Квартира
# 23367       23367       274672243   2, Оба варианта  Квартира
#
#                               Метро  \
# 0      м. Смоленская (9 мин пешком)
# 1      м. Смоленская (8 мин пешком)
# 2      м. Смоленская (7 мин пешком)
# 3      м. Смоленская (3 мин пешком)
# ...

# %%
df.shape
# Out:
# (23368, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23368 entries, 0 to 23367
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                23368 non-null  int64
#  1   ID  объявления            23368 non-null  int64
#  2   Количество комнат         22327 non-null  object
#  3   Тип                       23368 non-null  object
#  4   Метро                     22053 non-null  object
#  5   Адрес                     23368 non-null  object
#  6   Площадь, м2               23368 non-null  object
#  7   Дом                       23368 non-null  object
#  8   Парковка                  9951 non-null   object
#  9   Цена                      23368 non-null  object
#  10  Телефоны                  23368 non-null  object
#  11  Описание                  23368 non-null  object
#  12  Ремонт                    20613 non-null  object
# ...

# %%
# сводная статистика по числовым колонкам
df.describe(include='all')
# Out:
#           Unnamed: 0  ID  объявления Количество комнат       Тип  \
# count   23368.000000    2.336800e+04             22327     23368
# unique           NaN             NaN                24         1
# top              NaN             NaN                 1  Квартира
# freq             NaN             NaN              7917     23368
# mean    11683.500000    2.676265e+08               NaN       NaN
# std      6745.904881    1.876862e+07               NaN       NaN
# min         0.000000    1.072986e+08               NaN       NaN
# 25%      5841.750000    2.712663e+08               NaN       NaN
# 50%     11683.500000    2.739030e+08               NaN       NaN
# 75%     17525.250000    2.746872e+08               NaN       NaN
# max     23367.000000    2.750064e+08               NaN       NaN
#
#                                    Метро                           Адрес  \
# count                              22053                           23368
# ...

# %%
# сводная статистика по категориальным колонкам
df.describe(include='object')
# Out:
#        Количество комнат       Тип                             Метро  \
# count              22327     23368                             22053
# unique                24         1                              5866
# top                    1  Квартира  м. Академическая (10 мин пешком)
# freq                7917     23368                                41
#
#                                  Адрес     Площадь, м2             Дом  \
# count                            23368           23368           23368
# unique                           12850           11255            2565
# top     Москва, Чапаевский переулок, 3  40.0/20.0/10.0  3/5, Кирпичный
# freq                                63             224             322
#
#         Парковка                                               Цена  \
# count       9951                                              23368
# unique         5                                               3922
# ...

# %% [markdown]
# выносим отдельный столбец стоимость в месяц (без залога)

# %% [markdown]
# графики
# цена гистограмма
# цена к площади скатерплот
# цена к наличию лифта
# цена к наличию мусоропровода
#
# цена к высоте потолков
# цена относительно метро - метро и время в пути до метро
# цена относительно типа
# цена к ремонту

# %%
# график гистограмма цена
